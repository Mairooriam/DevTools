# %%
print("Hello World")
import pandas as pd
print(pd.__version__)
pdfPath = "data/test.pdf"
outPath = "output"
# Out:
# Hello World
# 3.0.0

# %%
from pathlib import Path
from typing import Optional
import time
from dataclasses import dataclass, field

@dataclass
class Ctx:
    rootPath: Path = field(default=Path('.').resolve())
    outputFileExtension: str = field(default=".xlsx")
    outputPathStr: str = field(default="output")
    dataPathStr: str = field(default='data')
    outputFile: str = field(default="file")
    customSuffix: Optional[str] = field(default=None) 

    @property
    def outputPath(self) -> Path:
        return self.rootPath / self.outputPathStr
    
    @property
    def dataPath(self) -> Path:
        return self.rootPath / self.dataPathStr

    @property
    def outputFilePath(self) -> Path:
        base_name = self.outputFile + self.outputFileExtension
        p = self.rootPath / self.outputPath / base_name
        if not p.exists():
            return p
        else:
            if self.customSuffix:
                formatted = self.customSuffix
            else:
                localTime = time.localtime()
                formatted = time.strftime('%Y_%m_%d_%X', localTime)
                formatted = formatted.replace(".", "")
            stem = p.stem  
            suffix = p.suffix 
            new_filename = f"{stem}_{formatted}{suffix}"
            return p.with_name(new_filename)
    

ctx = Ctx()


if not ctx.outputPath.exists() or not ctx.dataPath.exists():
    print(f"coulnd't find: {ctx.dataPath.resolve()}")
    print(f"coulnd't find: {ctx.outputPath.resolve()}")
    print(f"exiting..")
    #TODO: learn erorr handling in python
else:
    print(f"Place .pdf files in {ctx.dataPath.resolve()}")
    print(f"Processed .pdf files .xlsl will be places in {ctx.outputPath.resolve()}")

# file to save




# if str1 == str2:
#     #TODO: add stuff
#     localTime = time.localtime()
#     formatted = time.strftime('%Y_%m_%d_%X', localTime)
#     formatted = formatted.replace(".", "")
#     print(f"{str1}_{formatted}")




## 2026_01_02_1039
# Out:
# C:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsx\output\file.xlsx
# C:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsx\output\file.tatu
# Place .pdf files in C:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsx\data
# Processed .pdf files .xlsl will be places in C:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsx\output

# %%
import camelot.io as camelot

flavors = ['lattice', 'stream', 'network', 'hybrid']


ctx = Ctx()

localTime = time.localtime()
formatted = time.strftime('%Y_%m_%d_%X', localTime)
formatted = formatted.replace(".", "")
ctx.customSuffix = formatted
for flavor in flavors:
    tables = camelot.read_pdf(pdfPath, pages='1', parallel=True, flavor=flavor)
    ctx.outputFile = flavor
    tables.export(str(ctx.outputFilePath), f='excel')
    print(f"Exported {flavor} tables to {ctx.outputFilePath}")
# Out:
# hello
# hello
# Exported lattice tables to C:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\output\lattice_2026_02_01_131501.xlsx
# hello
# hello
# Exported stream tables to C:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\output\stream_2026_02_01_131501.xlsx
# hello
# hello
# Exported network tables to C:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\output\network_2026_02_01_131501.xlsx
# hello
# hello
# Exported hybrid tables to C:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\output\hybrid_2026_02_01_131501.xlsx

# %%
df = tables[0].df.copy() 
# Now you can use pandas methods like:
# df.head(), df.info(), df.describe(), etc.

test = df.index
test2 = df.columns
# types = df.dtypes
print(test)
print(test2)
# print(types)
row = df.loc[0].values
print(f"row: {row}")
print(f"axes: {df.axes}")
print(f"ndim: {df.ndim}")
print(f"size: {df.size}")
print(f"size tesT: {36*9}")
print(f"shape: {df.shape}")
print(f"head: {df.head(2)}")
print(f"t:5,5 {df.at[5,5]}")
print(f"t:5,5 {df.iat[5,5]}")
print(f"loc: {df.loc[[4,6],[5,6]]}")
hahaha = df.loc[0:35, [5]].copy()  # Ensure it's a copy

# Apply lambda to each cell (e.g., convert to uppercase if string)
hahaha_modified1 = hahaha.map(lambda x: 
                              x.upper() if isinstance(x, str) else x)
print(hahaha_modified1.head())

# Or, for a custom operation (e.g., add prefix)
hahaha_modified2 = hahaha.map(lambda x: f"prefix_{x}" if isinstance(x, str) else x)
print(hahaha_modified2.head())

print("\n\n")
# Check dtypes for each value in the first row
first_row = df.iloc[0]
for col, value in first_row.items():
    print(f"Column {col}: {type(value)} - {value}")

# Or, for a specific cell
print(f"Cell [0,0] type: {type(df.iloc[0, 0])}")
# Out:
# RangeIndex(start=0, stop=6, step=1)
# RangeIndex(start=0, stop=8, step=1)
# row: <StringArray>
# ['Cabinet:', '', '', '', '', '', '', '']
# Length: 8, dtype: str
# axes: [RangeIndex(start=0, stop=6, step=1), RangeIndex(start=0, stop=8, step=1)]
# ndim: 2
# size: 48
# size tesT: 324
# shape: (6, 8)
# head:           0 1 2 3 4 5 6 7
# 0  Cabinet:
# 1     =1+R1
# t:5,5 CPU
# t:5,5 CPU
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 21
#      19 print(f"t:5,5 {df.at[5,5]}")
#      20 print(f"t:5,5 {df.iat[5,5]}")
# ---> 21 print(f"loc: {df.loc[[4,6],[5,6]]}")
#      22 hahaha = df.loc[0:35, [5]].copy()  # Ensure it's a copy
#      24 # Apply lambda to each cell (e.g., convert to uppercase if string)
#
# File c:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\.venv\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File c:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\.venv\Lib\site-packages\pandas\core\indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
#    1385     tup = self._expand_ellipsis(tup)
# -> 1386     return self._getitem_lowerdim(tup)
#    1388 # no multi-index, so validate all of the indexers
#    1389 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\.venv\Lib\site-packages\pandas\core\indexing.py:1117, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1115             return section
#    1116         # This is an elided recursive call to iloc/loc
# -> 1117         return getattr(section, self.name)[new_key]
#    1119 raise IndexingError("not applicable")
#
# File c:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\.venv\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File c:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\.venv\Lib\site-packages\pandas\core\indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
#    1385     tup = self._expand_ellipsis(tup)
# -> 1386     return self._getitem_lowerdim(tup)
#    1388 # no multi-index, so validate all of the indexers
#    1389 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\.venv\Lib\site-packages\pandas\core\indexing.py:1093, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1089 for i, key in zip(range(len(tup) - 1, -1, -1), reversed(tup), strict=True):
#    1090     if is_label_like(key) or is_list_like(key):
#    1091         # We don't need to check for tuples here because those are
#    1092         #  caught by the _is_nested_tuple_indexer check above.
# -> 1093         section = self._getitem_axis(key, axis=i)
#    1095         # We should never have a scalar section here, because
#    1096         #  _getitem_lowerdim is only called after a check for
#    1097         #  is_scalar_access, which that would be.
#    1098         if section.ndim == self.ndim:
#    1099             # we're in the middle of slicing through a MultiIndex
#    1100             # revise the key wrt to `section` by inserting an _NS
#
# File c:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\.venv\Lib\site-packages\pandas\core\indexing.py:1438, in _LocIndexer._getitem_axis(self, key, axis)
#    1435     if hasattr(key, "ndim") and key.ndim > 1:
#    1436         raise ValueError("Cannot index with multidimensional key")
# -> 1438     return self._getitem_iterable(key, axis=axis)
#    1440 # nested tuple slicing
#    1441 if is_nested_tuple(key, labels):
#
# File c:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\.venv\Lib\site-packages\pandas\core\indexing.py:1378, in _LocIndexer._getitem_iterable(self, key, axis)
#    1375 self._validate_key(key, axis)
#    1377 # A collection of keys
# -> 1378 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1379 return self.obj._reindex_with_indexers(
#    1380     {axis: [keyarr, indexer]}, allow_dups=True
#    1381 )
#
# File c:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\.venv\Lib\site-packages\pandas\core\indexing.py:1576, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1573 ax = self.obj._get_axis(axis)
#    1574 axis_name = self.obj._get_axis_name(axis)
# -> 1576 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1578 return keyarr, indexer
#
# File c:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\.venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File c:\Users\35850\Desktop\repositories\DevTools\image_tables_into_xlsl\.venv\Lib\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: '[6] not in index'
